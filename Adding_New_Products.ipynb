# %% [markdown]
# # Read Data From record.json

# %%
fd = open("record.json","r")
txt=fd.read()
fd.close()

import json

json.loads(txt)  # json.loads converts string txt into dictionary
# Out:
# {'1001': {'name': 'Choco Cake', 'qn': 34, 'pr': 100},
#  '1002': {'name': 'Milk Cake', 'pr': 800, 'qn': 100},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 100},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 1000},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 100},
#  '1006': {'name': 'Phone', 'pr': 50000, 'qn': 10},
#  '1007': {'name': 'Mic', 'pr': 1500, 'qn': 0},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10}}

# %% [markdown]
# # Creating New record.json and Adding New Item into Inventory

# %%
product_id       =   input("Enter Product Id : ")
product_name     =   input("Enter product Name : ")
product_quantity =   input("Enter Total stock of "+product_id+" "+product_name+" : ")
product_price    =   input("Enter Price of "+product_id+" "+product_name+" : ")
product_exp_date =   input("Enter expiry date of product : ")
discount         =   input("Discount (in percentage): ")



for i in record.keys():
    if(i==product_id):
        record[i]['Product Quantity'] = str(int(record[i]['Product Quantity'])+int(product_quantity))### <<<---What if same product is added to inventory,then
        flag = 1

if(flag!=1):
        record[product_id]={'Product Name' : product_name , 'Product Quantity' : product_quantity , 'Price' : product_price , 'Exp_Date' : product_exp_date , 'Discount' : discount}
        
        

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter Product Id : 2035
# Enter product Name : Ethernet Cable
# Enter Total stock of 2035 Ethernet Cable : 50
# Enter Price of 2035 Ethernet Cable : 100
# Enter expiry date of product : Jan 2024
# Discount (in percentage): 10

# %%
record
# Out:
# {'1001': {'Product Name': 'Choco Cake',
#   'Product Quantity': '34',
#   'Price': '100',
#   'Exp_Date': 'Oct 2021',
#   'Discount': '10'},
#  '1002': {'Product Name': 'Milk Cake',
#   'Product Quantity': '100',
#   'Price': '800',
#   'Exp_Date': 'Oct 2021',
#   'Discount': '10'},
#  '1003': {'Product Name': 'Drink',
#   'Product Quantity': '100',
#   'Price': '85',
#   'Exp_Date': 'Feb 2021',
#   'Discount': '10'},
#  '1004': {'Product Name': 'Candy',
#   'Product Quantity': '1000',
#   'Price': '5',
#   'Exp_Date': 'Feb 2023',
#   'Discount': '0'},
#  '1005': {'Product Name': 'Pen',
#   'Product Quantity': '100',
#   'Price': '20',
#   'Exp_Date': 'Jan 2025',
#   'Discount': '10'},
#  '1006': {'Product Name': 'Phone',
#   'Product Quantity': '15',
#   'Price': '50000',
#   'Exp_Date': 'Sept 2024',
#   'Discount': '25'},
#  '1007': {'Product Name': 'Mic',
#   'Product Quantity': '1',
#   'Price': '1500',
#   'Exp_Date': 'Dec 2027',
#   'Discount': '10'},
# ...
